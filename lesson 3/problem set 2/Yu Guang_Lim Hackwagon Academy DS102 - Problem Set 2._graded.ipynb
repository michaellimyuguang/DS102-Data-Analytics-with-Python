# %% [markdown]
# <img src="https://i2.wp.com/hackwagon.com/wp-content/uploads/2017/02/Logo-Web-Export.png?ssl=1" width=200/>
#
# <h1>Hackwagon Academy DS102 - Problem Set 2</h1>
# <hr>
#
# This Problem Set consists of 10 questions, with 2 parts:
#
# 1. Data Wrangling & Preprocessing - 5 Questions, 1 mark each
# 2. Data Visualisation - 5 Questions, 3 marks each
#
# If you have any questions to the Problem Set, feel free to send a message to your TAs or Instructors in the Telegram chat. You are encouraged to also discuss the problem sets within your own groups.
#
# Before you seek help, please consider looking at online resources such as documentations and try out those solutions first. This will greatly enhance your learning experience. Being stuck is part of the learning experience so don't worry!
#
# <b>There are many ways to get to the right answer. Attempt but minor syntax errors are awarded half the mark.</b>

# %%
#Before you start, please perform the following 2 steps:
#1. Rename the file to FirstName_LastName Hackwagon Academy DS102 - Problem Set 2 e.g. John_Doe Hackwagon Academy DS102 - Problem Set 1

#2. Fill in your details here:
#Name                    : ___________Lim Yu Guang____________

#Start of Course Class(Edit accordingly): ___24 May 2020___

# FOR TA/INSTRUCTOR 
# Total Marks:  20 / 20

# %% [markdown]
# #### Credits
#
# This problem set is inspired by the [Lending Club Loan Data](https://www.kaggle.com/wendykan/lending-club-loan-data).

# %% [markdown]
# <img src="https://d1ic4altzx8ueg.cloudfront.net/niche-builder/5cb94cef96518.png" width=300>
#
# ## Context
#
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California. It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market.
#
# Having just joined their Data Science team, your first project is to help LendingClub prepare a prediction model to help them detect loan defaulters. Before attempting to create a model, you would first have to understand data you're working with.
#
# Having already conducted the initial data preprocessing (in PS1), your project manager, Silver, wants you to further analyse the data, this time on larger sample (`loans-200k.csv`). Based on your initial investigation, you've found out that the number of default loans is dependent on the grade of the loan. However, you believe that this analysis is insufficient, therefore you will be exploring several visualisation techniques to aid you in your analysis.
#
# The dataset handed to you are loans issued through 2007 - 2015 period including loan status. A data dictionary (`LCDataDictionary`) is also provided for you to get a better understanding of the dataset.
#
# Note: This problem set tackles both <b>Data Preprocessing and Descriptive Analytics</b> stages of the Data Science project.

# %% [markdown]
# ## Data Wrangling & Preprocessing - 5 marks
#
# Your first task as an analyst is to prepare the data into several different "sets". Using Pandas,

# %%
# Run this cell to remove the warning messages that could appear during your data cleaning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Q1. Open File and Inspect
#
# Open the file `loans-200k.csv` and store it as `all_loans_df`. Afterwhich, inspect the dataset for:
#
# 1. Number of rows and columns
# 2. Which columns contain missing values and how many missing values are there for each column

# %%
# Code here
import pandas as pd

all_loans_df = pd.read_csv("loans-200k.csv")

print(all_loans_df.shape)


all_loans_df.isnull().sum()
# Qns1
#rows = 200000
#columns =  19

# Qns2 - column name - number of missing values
# emp_length - 12895
# dti - 152
# delinq_2yrs - 4
# Out:
# (200000, 19)
# loan_amnt                      0
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# emp_length                 12895
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# purpose                        0
# dti                          152
# delinq_2yrs                    4
# loan_status                    0
# term_int                       0
# emp_length_int                 0
# home_ownership_int             0
# verification_status_int        0
# purpose_int                    0
# income_tax                     0
# dtype: int64

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: 1/1

# %% [markdown]
# ### Q2. Fill NA Values
#
# Based on the above findings, you decided to fill all the missing values for columns `dti` and `delinq_2yrs`.
#
# For `dti`, you want to fill the missing values with the <b>mean</b> of the `dti` column.
# For `delinq_2yrs`, you want to fill the missing values with `0`.

# %%
all_loans_df['dti'].fillna(all_loans_df['dti'].mean(), inplace=True)
all_loans_df['delinq_2yrs'].fillna(0, inplace=True)

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: 1/1

# %% [markdown]
# ### Q3. Round to Integer
#
# To simplify the analysis for interest rate in the `int_rate` column, you decide that you would round the rates to <b>the nearerest integer</b>, by creating a new column called `int_round`.
#
# <i>Hint: Use the apply method</i>
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/re1G9A8.png">

# %%
import math as m
def nearest_int(x):
    return m.floor(x)

all_loans_df['int_round'] = all_loans_df['int_rate'].apply(nearest_int)
all_loans_df
# Out:
#         loan_amnt        term  int_rate  installment grade emp_length  \
# 0           14400   36 months     14.47       495.46     C  10+ years
# 1            8000   36 months     10.75       260.97     B    3 years
# 2            9500   36 months     18.45       345.60     D    3 years
# 3           16000   60 months     18.99       414.97     D   < 1 year
# 4            6800   36 months     13.99       232.38     C  10+ years
# 5           20000   36 months     11.06       655.35     B        NaN
# 6           12000   36 months      8.39       378.20     B    4 years
# 7           40000   60 months     14.52       941.55     C     1 year
# 8           20000   60 months      9.17       416.82     B     1 year
# 9            6000   36 months     15.22       208.64     C    6 years
# 10          35000   60 months     24.08      1008.51     F    9 years
# 11           4000   36 months      6.67       122.91     A    6 years
# 12          15350   36 months     14.09       525.30     B  10+ years
# 13          14000   60 months     12.69       316.33     C   < 1 year
# 14           8400   36 months      9.17       267.79     B  10+ years
# 15          16000   60 months     13.67       369.57     C  10+ years
# 16          35000   60 months      7.35       698.84     A   < 1 year
# 17           8000   36 months     12.98       269.48     B        NaN
# 18           7000   36 months     13.49       237.52     C  10+ years
# 19          12000   36 months     15.04       416.22     C  10+ years
# 20          20000   36 months     22.74       771.49     E     1 year
# 21          20000   36 months     15.31       696.35     C    8 years
# 22           6000   36 months     11.80       198.72     B    2 years
# 23          18000   60 months     13.99       418.74     C    2 years
# 24           6000   36 months     14.09       205.33     B    2 years
# 25           7200   36 months      6.99       222.29     A  10+ years
# 26           6000   36 months     12.79       201.56     C    6 years
# 27          25000   36 months      7.59       778.69     A    3 years
# 28          24000   36 months      5.32       722.76     A        NaN
# 29           8000   36 months     11.80       264.96     B    5 years
# ...           ...         ...       ...          ...   ...        ...
# 199970      13500   60 months     22.35       375.55     D    8 years
# 199971      13000   36 months     11.44       428.32     B  10+ years
# 199972       5100   36 months      7.62       158.93     A    3 years
# 199973      24000   36 months     15.31       835.62     C     1 year
# 199974      16000   36 months      7.39       496.90     A    3 years
# 199975      15000   60 months     17.09       373.52     D        NaN
# 199976      14100   36 months     13.58       479.04     C    6 years
# 199977      18000   36 months      7.99       563.98     A  10+ years
# 199978      14000   36 months      8.24       440.27     B    6 years
# 199979      30000   60 months     19.92       793.49     D  10+ years
# 199980      20000   60 months     13.99       465.27     C   < 1 year
# 199981      10000   36 months      5.32       301.15     A    4 years
# 199982       9000   36 months      7.14       278.48     A  10+ years
# 199983       6000   36 months     12.74       201.42     C   < 1 year
# 199984      25000   36 months      6.07       761.35     A    5 years
# 199985      12000   60 months     11.47       263.74     B    5 years
# 199986      35000   36 months     16.55      1240.03     D  10+ years
# 199987      10000   60 months     19.22       260.62     D    8 years
# 199988      15000   36 months      6.99       463.09     A  10+ years
# 199989      29025   36 months      6.89       894.75     A    8 years
# 199990      16000   60 months     17.56       402.48     D    8 years
# 199991      15000   60 months     11.99       333.60     B    5 years
# 199992       8200   36 months     17.57       294.69     D        NaN
# 199993      35000   36 months     15.61      1223.77     D  10+ years
# 199994      20000   36 months     15.99       703.05     C  10+ years
# 199995      12000   36 months     13.99       410.08     C    5 years
# 199996      30000   36 months      7.89       938.57     A    9 years
# 199997       9600   36 months     14.99       332.75     C    4 years
# 199998      10000   36 months      8.39       315.17     B    7 years
# 199999      25000   60 months     16.59       615.82     D    9 years
#
#        home_ownership  annual_inc verification_status             purpose  \
# 0            MORTGAGE    109000.0     Source Verified  debt_consolidation
# 1            MORTGAGE     50000.0     Source Verified         credit_card
# 2            MORTGAGE    138000.0     Source Verified         credit_card
# 3                 OWN     66000.0        Not Verified  debt_consolidation
# 4            MORTGAGE     63000.0        Not Verified  debt_consolidation
# 5            MORTGAGE     64314.0            Verified  debt_consolidation
# 6            MORTGAGE     65000.0            Verified         credit_card
# 7            MORTGAGE    260000.0        Not Verified  debt_consolidation
# 8                RENT    100000.0     Source Verified  debt_consolidation
# 9                 OWN     50000.0        Not Verified  debt_consolidation
# 10               RENT    100000.0            Verified         credit_card
# 11               RENT     56500.0        Not Verified  debt_consolidation
# 12           MORTGAGE     45000.0            Verified  debt_consolidation
# 13           MORTGAGE     55700.0     Source Verified         credit_card
# 14           MORTGAGE     55000.0        Not Verified         credit_card
# 15           MORTGAGE     73000.0        Not Verified         credit_card
# 16           MORTGAGE     28000.0            Verified  debt_consolidation
# 17               RENT     60000.0        Not Verified               other
# 18           MORTGAGE     60000.0            Verified    home_improvement
# 19           MORTGAGE     75000.0     Source Verified  debt_consolidation
# 20               RENT     64000.0     Source Verified  debt_consolidation
# 21               RENT     53604.0            Verified  debt_consolidation
# 22           MORTGAGE     37440.0     Source Verified         credit_card
# 23               RENT    150000.0     Source Verified  debt_consolidation
# 24               RENT     45000.0            Verified         credit_card
# 25           MORTGAGE     78000.0        Not Verified         credit_card
# 26           MORTGAGE     45000.0        Not Verified  debt_consolidation
# 27               RENT     95000.0        Not Verified         credit_card
# 28               RENT     65000.0            Verified  debt_consolidation
# 29               RENT     28000.0     Source Verified  debt_consolidation
# ...               ...         ...                 ...                 ...
# 199970           RENT     85000.0        Not Verified               other
# 199971       MORTGAGE     50000.0        Not Verified         credit_card
# 199972           RENT     30000.0            Verified  debt_consolidation
# 199973           RENT     79000.0            Verified  debt_consolidation
# 199974           RENT     89000.0            Verified         credit_card
# 199975           RENT     80000.0     Source Verified    home_improvement
# 199976           RENT     42000.0        Not Verified         credit_card
# 199977           RENT     93000.0            Verified  debt_consolidation
# 199978            OWN     65000.0     Source Verified  debt_consolidation
# 199979       MORTGAGE    120000.0            Verified  debt_consolidation
# 199980       MORTGAGE    180000.0        Not Verified  debt_consolidation
# 199981           RENT     70000.0     Source Verified         credit_card
# 199982            OWN     51000.0        Not Verified  debt_consolidation
# 199983           RENT     28080.0     Source Verified  debt_consolidation
# 199984       MORTGAGE    270000.0     Source Verified    home_improvement
# 199985       MORTGAGE     57000.0        Not Verified  debt_consolidation
# 199986       MORTGAGE    153000.0     Source Verified  debt_consolidation
# 199987           RENT     42000.0            Verified  debt_consolidation
# 199988       MORTGAGE    130000.0        Not Verified    home_improvement
# 199989       MORTGAGE    120000.0            Verified  debt_consolidation
# 199990       MORTGAGE    130000.0            Verified  debt_consolidation
# 199991       MORTGAGE     64000.0     Source Verified         credit_card
# 199992       MORTGAGE     74400.0            Verified    home_improvement
# 199993       MORTGAGE    118868.0     Source Verified    home_improvement
# 199994       MORTGAGE     65000.0     Source Verified  debt_consolidation
# 199995       MORTGAGE     44500.0        Not Verified  debt_consolidation
# 199996       MORTGAGE     96500.0            Verified  debt_consolidation
# 199997           RENT     33000.0            Verified  debt_consolidation
# 199998           RENT     75000.0        Not Verified  debt_consolidation
# 199999       MORTGAGE     76800.0        Not Verified  debt_consolidation
#
#           dti  delinq_2yrs  loan_status  term_int  emp_length_int  \
# 0        8.52          1.0      Current         0              10
# 1       17.31          0.0      Current         0               3
# 2       23.91          0.0      Current         0               3
# 3       33.65          0.0      Current         1               0
# 4       19.68          0.0      Current         0              10
# 5       19.76          0.0      Current         0              -1
# 6       22.64          0.0   Fully Paid         0               4
# 7        6.32          0.0      Current         1               1
# 8       16.92          0.0   Fully Paid         1               1
# 9        9.89          0.0   Fully Paid         0               6
# 10      26.28          1.0  Charged Off         1               9
# 11       6.01          0.0      Current         0               6
# 12      18.13          0.0   Fully Paid         0              10
# 13      20.43          0.0      Current         1               0
# 14      21.25          0.0  Charged Off         0              10
# 15      17.46          1.0  Charged Off         1              10
# 16      65.88          0.0      Current         1               0
# 17       8.40          0.0      Current         0              -1
# 18      31.26          0.0  Charged Off         0              10
# 19      13.73          0.0      Current         0              10
# 20      26.27          0.0      Current         0               1
# 21      19.27          1.0   Fully Paid         0               8
# 22       5.77          0.0      Current         0               2
# 23       6.72          0.0      Current         1               2
# 24      14.80          0.0   Fully Paid         0               2
# 25      11.72          0.0   Fully Paid         0              10
# 26      26.64          0.0   Fully Paid         0               6
# 27      23.59          0.0   Fully Paid         0               3
# 28      19.87          0.0   Fully Paid         0              -1
# 29       7.80          0.0      Current         0               5
# ...       ...          ...          ...       ...             ...
# 199970   8.64          0.0      Current         1               8
# 199971  18.75          0.0   Fully Paid         0              10
# 199972  12.88          0.0   Fully Paid         0               3
# 199973  10.92          3.0   Fully Paid         0               1
# 199974  17.98          0.0      Current         0               3
# 199975  19.85          0.0      Current         1              -1
# 199976  30.54          0.0  Charged Off         0               6
# 199977   5.26          0.0   Fully Paid         0              10
# 199978  17.43          0.0      Current         0               6
# 199979  27.43          1.0      Current         1              10
# 199980  10.27          0.0   Fully Paid         1               0
# 199981   5.01          0.0   Fully Paid         0               4
# 199982   7.20          0.0   Fully Paid         0              10
# 199983  19.66          0.0   Fully Paid         0               0
# 199984   5.77          0.0      Current         0               5
# 199985  20.00          0.0      Current         1               5
# 199986  14.75          1.0  Charged Off         0              10
# 199987  22.48          0.0  Charged Off         1               8
# 199988  16.40          0.0      Current         0              10
# 199989  14.76          0.0   Fully Paid         0               8
# 199990  29.12          0.0   Fully Paid         1               8
# 199991  29.48          0.0      Current         1               5
# 199992  20.76          3.0   Fully Paid         0              -1
# 199993  13.88          0.0   Fully Paid         0              10
# 199994  16.95          0.0   Fully Paid         0              10
# 199995  15.91          0.0   Fully Paid         0               5
# 199996  22.30          0.0   Fully Paid         0               9
# 199997  22.47          0.0   Fully Paid         0               4
# 199998  14.21          0.0      Current         0               7
# 199999  36.95          0.0      Current         1               9
#
#         home_ownership_int  verification_status_int  purpose_int  income_tax  \
# 0                        0                        1            1      8175.0
# 1                        0                        1            3         0.0
# 2                        0                        1            3     10350.0
# 3                        1                        2            1      4950.0
# 4                        0                        2            1         0.0
# 5                        0                        0            1         0.0
# 6                        0                        0            3         0.0
# 7                        0                        2            1     19500.0
# 8                        2                        1            1      7500.0
# 9                        1                        2            1         0.0
# 10                       2                        0            3      7500.0
# 11                       2                        2            1         0.0
# 12                       0                        0            1         0.0
# 13                       0                        1            3         0.0
# 14                       0                        2            3         0.0
# 15                       0                        2            3      5475.0
# 16                       0                        0            1         0.0
# 17                       2                        2            0         0.0
# 18                       0                        0            2         0.0
# 19                       0                        1            1      5625.0
# 20                       2                        1            1         0.0
# 21                       2                        0            1         0.0
# 22                       0                        1            3         0.0
# 23                       2                        1            1     11250.0
# 24                       2                        0            3         0.0
# 25                       0                        2            3      5850.0
# 26                       0                        2            1         0.0
# 27                       2                        2            3      7125.0
# 28                       2                        0            1         0.0
# 29                       2                        1            1         0.0
# ...                    ...                      ...          ...         ...
# 199970                   2                        2            0      6375.0
# 199971                   0                        2            3         0.0
# 199972                   2                        0            1         0.0
# 199973                   2                        0            1      5925.0
# 199974                   2                        0            3      6675.0
# 199975                   2                        1            2      6000.0
# 199976                   2                        2            3         0.0
# 199977                   2                        0            1      6975.0
# 199978                   1                        1            1         0.0
# 199979                   0                        0            1      9000.0
# 199980                   0                        2            1     13500.0
# 199981                   2                        1            3      5250.0
# 199982                   1                        2            1         0.0
# 199983                   2                        1            1         0.0
# 199984                   0                        1            2     20250.0
# 199985                   0                        2            1         0.0
# 199986                   0                        1            1     11475.0
# 199987                   2                        0            1         0.0
# 199988                   0                        2            2      9750.0
# 199989                   0                        0            1      9000.0
# 199990                   0                        0            1      9750.0
# 199991                   0                        1            3         0.0
# 199992                   0                        0            2      5580.0
# 199993                   0                        1            2      8915.1
# 199994                   0                        1            1         0.0
# 199995                   0                        2            1         0.0
# 199996                   0                        0            1      7237.5
# 199997                   2                        0            1         0.0
# 199998                   2                        2            1      5625.0
# 199999                   0                        2            1      5760.0
#
#         int_round
# 0              14
# 1              10
# 2              18
# 3              18
# 4              13
# 5              11
# 6               8
# 7              14
# 8               9
# 9              15
# 10             24
# 11              6
# 12             14
# 13             12
# 14              9
# 15             13
# 16              7
# 17             12
# 18             13
# 19             15
# 20             22
# 21             15
# 22             11
# 23             13
# 24             14
# 25              6
# 26             12
# 27              7
# 28              5
# 29             11
# ...           ...
# 199970         22
# 199971         11
# 199972          7
# 199973         15
# 199974          7
# 199975         17
# 199976         13
# 199977          7
# 199978          8
# 199979         19
# 199980         13
# 199981          5
# 199982          7
# 199983         12
# 199984          6
# 199985         11
# 199986         16
# 199987         19
# 199988          6
# 199989          6
# 199990         17
# 199991         11
# 199992         17
# 199993         15
# 199994         15
# 199995         13
# 199996          7
# 199997         14
# 199998          8
# 199999         16
#
# [200000 rows x 20 columns]

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: 1/1

# %% [markdown]
# ### Q4. Prepare Target Column
#
# After inspecting the `loan_status` column, you realised that there are 9 unique values. To simplify your analysis, you decided that there should only be 2 unique values: `Default` and `Not Default`. You decide to create a new column called `target`, which would be used in your machine learning model.
#
# To create this column, you decide that <b>if</b> the value contains the word `Charged Off` or `Status:Charged Off`, it will be `Default`; <b>else</b> it will be `Non Default`.
#
# <i>Hint: Use the apply method</i>
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/bmYrw9d.png">

# %%
# For your function
def target_generator(x):
    if 'Charged Off' in x:
        return "Default"
    elif "Status:Charged Off" in x:
        return "Default"
    else:
        return "Non Default"

# %%
# For creating a new column 
all_loans_df['target'] = all_loans_df['loan_status'].apply(target_generator)

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: 1/1

# %% [markdown]
# ### Q5. Save CSV
#
# Save the transformed dataset as a new CSV file as `loans_transformed-200k.csv`.

# %%
all_loans_df.to_csv("loans_transformed-200k.csv", index=False)

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: 1/1

# %% [markdown]
# ## Visualisation - 15 marks
#
# There are a total of 3 sections for each of the next 5 questions/cells where <b>each correct section is awarded 1 mark</b>:
#
# - Section 1 - Prepare Data
# - Section 2 - Visualise (<b>You must have the appropriate Title, X and Y labels to be awarded full point for visualisation</b>)
# - Section 3 - Save Figure

# %% [markdown]
# ### Question 6 - Proportion of Default Loans for Each Grade
#
# You want to visually analyse how many loans are defaulted for each grade in a barchart.

# %% [markdown]
# ### Section 1 - Prepare Data
#
# Similar to Q18 of PSet 1, you want to get the proportion of `Default` loans for each grade.
#
# 1. Create 2 variables/series using `groupby`:
#     - A: Total loans of each grade,
#     - B: Default loans for each grade
# 2. Create a series where it B / A
#
# <b>Expected Output:</b>
#
#     grade
#     A    0.031707
#     B    0.078366
#     C    0.129419
#     D    0.181944
#     E    0.271083
#     F    0.346859
#     G    0.370010
#     dtype: float64

# %%
grade_gb = all_loans_df.groupby('grade')
size_of_grade = grade_gb.size()
#print(size_of_grade) #size of each grade

cond = (all_loans_df['target'] == 'Default')
filtered_df = all_loans_df[cond]
filtered_grade_gb = filtered_df.groupby('grade')
size_of_filtered_grade = filtered_grade_gb.size()
#print(size_of_filtered_grade) #size of default categorised by grade

size_of_grade = size_of_filtered_grade / size_of_grade

print(size_of_grade)
# Out:
# grade
# A    0.031707
# B    0.078366
# C    0.129419
# D    0.181944
# E    0.271083
# F    0.346859
# G    0.370010
# dtype: float64

# %% [markdown]
# ### Section 2 & 3 - Visualise and Save Figure
#
# Visualise the expected bar chart using the above Series and save it as `default_loans_proportion.png`.
#
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/c9YRxjp.png">

# %%
# -------------- #
### SECTION 2 ###
## VISUALISE ## 
# -------------- #
import matplotlib.pyplot as plt

flatten_df = size_of_grade.reset_index()
flatten_df.columns = ['Grade', 'Proportion']

plot = flatten_df.plot(kind='bar',
                       x='Grade',
                       y='Proportion',
                      legend=False)

plot.set(title='Proportion of Default Loans for Each Grade', ylabel="% of Loans")

# -------------- #
### SECTION 3 ###
## SAVE FIGURE ## 
# -------------- #
plt.savefig('default_loans_proportion.png')

# %%
## TA/INSTRUCTOR ONLY
## SECTION 1: 1/1
## SECTION 2: 1/1
## SECTION 3: 1/1

# %% [markdown]
# ### Question 7 - Proportion of 36 months vs. 60 months loans for each grade
#
# You would like to investigate the proportion of loans for each grade based on their. terms.

# %% [markdown]
# ### Section 1 - Prepare Data
#
# Prepare a new DataFrame by:
#
# 1. Create 3 Series
#     - A: A groupby grade on <b>all</b> loans and get their `.size()`
#     - B: A groupby grade on <b>`' 36 months'`  term</b> loans and get their `.size()`
#     - C: A groupby grade on <b>`' 60 months'`  term</b> loans and get their `.size()`
#
#
# 2. Create a new DataFrame with these 3 series with the column names:
#     - A: Total Loans
#     - B: 36 Months
#     - C: 60 Months
#
#
# 3. Create two new columns:
#     - `36 months percentage`: where it is the `36 months` / `Total Loans`
#     - `60 months percentage`: where it is the `60 months` / `Total Loans`
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/QSR74jG.png">

# %%
total_loans = all_loans_df.groupby("grade").size()
cond1 = all_loans_df["term"]==' 36 months'
cond2 = all_loans_df["term"]==' 60 months'

mth_36 = all_loans_df[cond1].groupby("grade").size()
mth_60 = all_loans_df[cond2].groupby("grade").size()
#print(total_loans)
#print(mth_36)
#print(mth_60)

percent_36 = mth_36 / total_loans * 100
percent_60 = mth_60 / total_loans * 100

#print(percent_36)
#print(percent_60)

new_df = pd.DataFrame({'Total Loans':total_loans,
                       '36 Months':mth_36,
                      '60 Months':mth_60})

#print(new_df)

new_df['36 months percentage'] = percent_36
new_df['60 months percentage'] = percent_60

print(new_df)
# Out:
#        Total Loans  36 Months  60 Months  36 months percentage  \
# grade
# A            38162      36064       2098             94.502385
# B            58533      47119      11414             80.499889
# C            57673      37203      20470             64.506788
# D            28844      16403      12441             56.867979
# E            11941       4475       7466             37.475923
# F             3820        788       3032             20.628272
# G             1027        177        850             17.234664
#
#        60 months percentage
# grade
# A                  5.497615
# B                 19.500111
# C                 35.493212
# D                 43.132021
# E                 62.524077
# F                 79.371728
# G                 82.765336

# %% [markdown]
# ### Section 2 & 3 - Visualise and Save Figure
#
# From the DataFrame above, isolate to just the `'36 months percentage'` and `'60 months percentage'` columns (i.e create new DataFrame with just these 2 columns). Plot a `stacked` bar chart as expected in the output. Save the visualisation as `proportion_of_loan_terms_by_grade.png`
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/ZWMZa65.png" width=500>

# %%
# -------------- #
### SECTION 2 ###
## VISUALISE ## 
# -------------- #
figure = plt.figure(figsize=(20,10))
ax = figure.add_subplot(1, 1, 1)
isolate_df = new_df[['36 months percentage', '60 months percentage']]
flatten_df = isolate_df.reset_index()

#print(flatten_df)
plot = flatten_df.plot(kind='bar',
                       x='grade',
                       stacked=True,
                      ax=ax)

plot.set(title='Proportion of Loan Terms by Grade', xlabel="Proportion of Loans (%)", ylabel="Grade", yticks=range(0,140,20))

# -------------- #
### SECTION 3 ###
## SAVE FIGURE ## 
# -------------- #

plt.savefig('proportion_of_loan_terms_by_grade.png')

# %%
## TA/INSTRUCTOR ONLY
## SECTION 1: 1/1
## SECTION 2: 1/1
## SECTION 3: 1/1

# %% [markdown]
# ### Question 8 - Correlation Matrix on Numeric Variables
#
# You would like to investigate if there are variables/columns that could be highly correlated with one another as this would aid in preparation for the machine learning step later in the project. You decide to plot a correlation matrix only on the numeric variables.

# %% [markdown]
# ### Section 1 - Prepare Data
#
# Filter only for only numeric columns then apply the `.corr()` method on the dataframe. Store this new DataFrame as `loans_numeric_df_corr`.
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/pxirI21.png">

# %%
# -------------- #
### SECTION 1 ###
## PREPARE DATA ##
# -------------- #
numerics = ['int64', 'float64']
select_df = all_loans_df.select_dtypes(include=numerics)
loans_numeric_df_corr = select_df.corr(method='pearson')

loans_numeric_df_corr
# Out:
#                          loan_amnt  int_rate  installment  annual_inc  \
# loan_amnt                 1.000000  0.102147     0.945309    0.297299
# int_rate                  0.102147  1.000000     0.128519   -0.074050
# installment               0.945309  0.128519     1.000000    0.287981
# annual_inc                0.297299 -0.074050     0.287981    1.000000
# dti                       0.046036  0.131959     0.046240   -0.126740
# delinq_2yrs              -0.011041  0.058324     0.001215    0.042887
# term_int                  0.393135  0.372065     0.137494    0.052783
# emp_length_int            0.103648 -0.012209     0.088738    0.099099
# home_ownership_int       -0.176330  0.078754    -0.140871   -0.137177
# verification_status_int  -0.200412 -0.246907    -0.211002   -0.031061
# purpose_int              -0.073926 -0.053684    -0.073168    0.006112
# income_tax                0.344441 -0.083131     0.332170    0.964147
# int_round                 0.102241  0.997859     0.128333   -0.073720
#
#                               dti  delinq_2yrs  term_int  emp_length_int  \
# loan_amnt                0.046036    -0.011041  0.393135        0.103648
# int_rate                 0.131959     0.058324  0.372065       -0.012209
# installment              0.046240     0.001215  0.137494        0.088738
# annual_inc              -0.126740     0.042887  0.052783        0.099099
# dti                      1.000000    -0.013664  0.065076       -0.013695
# delinq_2yrs             -0.013664     1.000000 -0.012145        0.031006
# term_int                 0.065076    -0.012145  1.000000        0.067382
# emp_length_int          -0.013695     0.031006  0.067382        1.000000
# home_ownership_int      -0.028134    -0.045328 -0.109102       -0.169891
# verification_status_int -0.073172    -0.017635 -0.097017        0.016987
# purpose_int             -0.043297    -0.007990 -0.050793       -0.035910
# income_tax              -0.131139     0.049307  0.062977        0.110426
# int_round                0.131822     0.057085  0.371804       -0.012843
#
#                          home_ownership_int  verification_status_int  \
# loan_amnt                         -0.176330                -0.200412
# int_rate                           0.078754                -0.246907
# installment                       -0.140871                -0.211002
# annual_inc                        -0.137177                -0.031061
# dti                               -0.028134                -0.073172
# delinq_2yrs                       -0.045328                -0.017635
# term_int                          -0.109102                -0.097017
# emp_length_int                    -0.169891                 0.016987
# home_ownership_int                 1.000000                 0.012618
# verification_status_int            0.012618                 1.000000
# purpose_int                        0.039816                 0.018222
# income_tax                        -0.161613                -0.033519
# int_round                          0.078553                -0.244468
#
#                          purpose_int  income_tax  int_round
# loan_amnt                  -0.073926    0.344441   0.102241
# int_rate                   -0.053684   -0.083131   0.997859
# installment                -0.073168    0.332170   0.128333
# annual_inc                  0.006112    0.964147  -0.073720
# dti                        -0.043297   -0.131139   0.131822
# delinq_2yrs                -0.007990    0.049307   0.057085
# term_int                   -0.050793    0.062977   0.371804
# emp_length_int             -0.035910    0.110426  -0.012843
# home_ownership_int          0.039816   -0.161613   0.078553
# verification_status_int     0.018222   -0.033519  -0.244468
# purpose_int                 1.000000    0.006697  -0.053162
# income_tax                  0.006697    1.000000  -0.082802
# int_round                  -0.053162   -0.082802   1.000000

# %% [markdown]
# ### Section 2 - Visualise
#
# This is different from visualising with `matplotlib`.
#
# The correlation matrix in the expected output is a <b>DataFrame</b> with color formatting. As such, to visualise the matrix, you would have to display it either by, putting the variable on the last line of the cell or using the `display()` function.
#
# <b>Expected Output:</b>
# <img src="https://i.imgur.com/NsLHKSw.png" width=800>

# %%
# -------------- #
### SECTION 2 ###
## VISUALISE ## 
# -------------- #
pd.set_option('precision', 6)
loans_numeric_df_corr = loans_numeric_df_corr.style.background_gradient(cmap = 'coolwarm')
loans_numeric_df_corr
# Out:
# <style  type="text/css" >
#     #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col2 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col3 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col5 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col6 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col9 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col11 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row0_col12 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col2 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col5 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col6 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col8 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col10 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col11 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row1_col12 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col0 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col1 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col3 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col6 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col8 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col9 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col11 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row2_col12 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col0 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col2 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col6 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col7 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col8 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col9 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col10 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col11 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row3_col12 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col0 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col1 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col2 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col3 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_2f30f49a_b24a_11ea_bac9_a45e60c54cf1row4_col7 {
#             background-color:  #6485ec;
#             color:

# %% [markdown]
# ### Section 3 - Save Figure
#
# Since the above correlation matrix is a DataFrame, to save the styling and formatting of the DataFrame, we can save it as an excel by using `.to_excel()` with the file name `corr_matrix.xlsx`.

# %%
# -------------- #
### SECTION 3 ###
## SAVE FIGURE ## 
# -------------- #
loans_numeric_df_corr.to_excel("corr_matrix.xlsx")

# %%
## TA/INSTRUCTOR ONLY
## SECTION 1: 1/1
## SECTION 2: 1/1
## SECTION 3: 1/1

# %% [markdown]
# <div class="alert alert-block alert-info">
# For the next two questions, you will be using the <b>Seaborn</b> library to plot your graphs, so please import the library. Seaborn works in a similar way to pandas too.
# </div>
#
# ```python
# import seaborn as sns
# ```
# The specific methods are `sns.distplot()` and `sns.countplot()`.
#
# Here are the documentation links for the two methods:
# - `sns.distplot()`  - https://seaborn.pydata.org/generated/seaborn.distplot.html
# - `sns.countplot()` - https://seaborn.pydata.org/generated/seaborn.countplot.html

# %% [markdown]
# ### Question 9 - Non-Default vs. Default Loan Distribution
#
# You would like to compare difference in loan amounts and interest rates for default and non default loans.

# %% [markdown]
# ### Section 1 - Prepare Data
#
# Create two dataframes:
#
# 1. `non_default_df` where `target` is `Non Default`
# 2. `default_df` where `target` is `Default`

# %%
import seaborn as sns
all_loans_df.head()
cond1 = (all_loans_df['target'] == 'Non Default')
cond2 = (all_loans_df['target'] == 'Default')
non_default_df = all_loans_df[cond1]
default_df = all_loans_df[cond2]

print(non_default_df)
print(default_df)
# Out:
#         loan_amnt        term  int_rate  installment grade emp_length  \
# 0           14400   36 months     14.47       495.46     C  10+ years
# 1            8000   36 months     10.75       260.97     B    3 years
# 2            9500   36 months     18.45       345.60     D    3 years
# 3           16000   60 months     18.99       414.97     D   < 1 year
# 4            6800   36 months     13.99       232.38     C  10+ years
# 5           20000   36 months     11.06       655.35     B        NaN
# 6           12000   36 months      8.39       378.20     B    4 years
# 7           40000   60 months     14.52       941.55     C     1 year
# 8           20000   60 months      9.17       416.82     B     1 year
# 9            6000   36 months     15.22       208.64     C    6 years
# 11           4000   36 months      6.67       122.91     A    6 years
# 12          15350   36 months     14.09       525.30     B  10+ years
# 13          14000   60 months     12.69       316.33     C   < 1 year
# 16          35000   60 months      7.35       698.84     A   < 1 year
# 17           8000   36 months     12.98       269.48     B        NaN
# 19          12000   36 months     15.04       416.22     C  10+ years
# 20          20000   36 months     22.74       771.49     E     1 year
# 21          20000   36 months     15.31       696.35     C    8 years
# 22           6000   36 months     11.80       198.72     B    2 years
# 23          18000   60 months     13.99       418.74     C    2 years
# 24           6000   36 months     14.09       205.33     B    2 years
# 25           7200   36 months      6.99       222.29     A  10+ years
# 26           6000   36 months     12.79       201.56     C    6 years
# 27          25000   36 months      7.59       778.69     A    3 years
# 28          24000   36 months      5.32       722.76     A        NaN
# 29           8000   36 months     11.80       264.96     B    5 years
# 30          35000   60 months     17.57       880.61     D    8 years
# 31          20000   60 months      8.18       407.26     B    3 years
# 32           2500   36 months     15.61        87.42     D    5 years
# 33          25000   60 months     12.29       559.79     C  10+ years
# ...           ...         ...       ...          ...   ...        ...
# 199966      25000   60 months     13.33       573.06     C    5 years
# 199967      24000   60 months     12.74       542.89     C    6 years
# 199968      35000   60 months     11.44       768.69     B  10+ years
# 199970      13500   60 months     22.35       375.55     D    8 years
# 199971      13000   36 months     11.44       428.32     B  10+ years
# 199972       5100   36 months      7.62       158.93     A    3 years
# 199973      24000   36 months     15.31       835.62     C     1 year
# 199974      16000   36 months      7.39       496.90     A    3 years
# 199975      15000   60 months     17.09       373.52     D        NaN
# 199977      18000   36 months      7.99       563.98     A  10+ years
# 199978      14000   36 months      8.24       440.27     B    6 years
# 199979      30000   60 months     19.92       793.49     D  10+ years
# 199980      20000   60 months     13.99       465.27     C   < 1 year
# 199981      10000   36 months      5.32       301.15     A    4 years
# 199982       9000   36 months      7.14       278.48     A  10+ years
# 199983       6000   36 months     12.74       201.42     C   < 1 year
# 199984      25000   36 months      6.07       761.35     A    5 years
# 199985      12000   60 months     11.47       263.74     B    5 years
# 199988      15000   36 months      6.99       463.09     A  10+ years
# 199989      29025   36 months      6.89       894.75     A    8 years
# 199990      16000   60 months     17.56       402.48     D    8 years
# 199991      15000   60 months     11.99       333.60     B    5 years
# 199992       8200   36 months     17.57       294.69     D        NaN
# 199993      35000   36 months     15.61      1223.77     D  10+ years
# 199994      20000   36 months     15.99       703.05     C  10+ years
# 199995      12000   36 months     13.99       410.08     C    5 years
# 199996      30000   36 months      7.89       938.57     A    9 years
# 199997       9600   36 months     14.99       332.75     C    4 years
# 199998      10000   36 months      8.39       315.17     B    7 years
# 199999      25000   60 months     16.59       615.82     D    9 years
#
#        home_ownership  annual_inc verification_status             purpose  \
# 0            MORTGAGE    109000.0     Source Verified  debt_consolidation
# 1            MORTGAGE     50000.0     Source Verified         credit_card
# 2            MORTGAGE    138000.0     Source Verified         credit_card
# 3                 OWN     66000.0        Not Verified  debt_consolidation
# 4            MORTGAGE     63000.0        Not Verified  debt_consolidation
# 5            MORTGAGE     64314.0            Verified  debt_consolidation
# 6            MORTGAGE     65000.0            Verified         credit_card
# 7            MORTGAGE    260000.0        Not Verified  debt_consolidation
# 8                RENT    100000.0     Source Verified  debt_consolidation
# 9                 OWN     50000.0        Not Verified  debt_consolidation
# 11               RENT     56500.0        Not Verified  debt_consolidation
# 12           MORTGAGE     45000.0            Verified  debt_consolidation
# 13           MORTGAGE     55700.0     Source Verified         credit_card
# 16           MORTGAGE     28000.0            Verified  debt_consolidation
# 17               RENT     60000.0        Not Verified               other
# 19           MORTGAGE     75000.0     Source Verified  debt_consolidation
# 20               RENT     64000.0     Source Verified  debt_consolidation
# 21               RENT     53604.0            Verified  debt_consolidation
# 22           MORTGAGE     37440.0     Source Verified         credit_card
# 23               RENT    150000.0     Source Verified  debt_consolidation
# 24               RENT     45000.0            Verified         credit_card
# 25           MORTGAGE     78000.0        Not Verified         credit_card
# 26           MORTGAGE     45000.0        Not Verified  debt_consolidation
# 27               RENT     95000.0        Not Verified         credit_card
# 28               RENT     65000.0            Verified  debt_consolidation
# 29               RENT     28000.0     Source Verified  debt_consolidation
# 30           MORTGAGE     75000.0            Verified         credit_card
# 31           MORTGAGE     75000.0        Not Verified  debt_consolidation
# 32           MORTGAGE     90000.0            Verified    home_improvement
# 33           MORTGAGE     65000.0        Not Verified         credit_card
# ...               ...         ...                 ...                 ...
# 199966       MORTGAGE    160000.0        Not Verified  debt_consolidation
# 199967       MORTGAGE     80000.0     Source Verified  debt_consolidation
# 199968       MORTGAGE    110000.0            Verified         credit_card
# 199970           RENT     85000.0        Not Verified               other
# 199971       MORTGAGE     50000.0        Not Verified         credit_card
# 199972           RENT     30000.0            Verified  debt_consolidation
# 199973           RENT     79000.0            Verified  debt_consolidation
# 199974           RENT     89000.0            Verified         credit_card
# 199975           RENT     80000.0     Source Verified    home_improvement
# 199977           RENT     93000.0            Verified  debt_consolidation
# 199978            OWN     65000.0     Source Verified  debt_consolidation
# 199979       MORTGAGE    120000.0            Verified  debt_consolidation
# 199980       MORTGAGE    180000.0        Not Verified  debt_consolidation
# 199981           RENT     70000.0     Source Verified         credit_card
# 199982            OWN     51000.0        Not Verified  debt_consolidation
# 199983           RENT     28080.0     Source Verified  debt_consolidation
# 199984       MORTGAGE    270000.0     Source Verified    home_improvement
# 199985       MORTGAGE     57000.0        Not Verified  debt_consolidation
# 199988       MORTGAGE    130000.0        Not Verified    home_improvement
# 199989       MORTGAGE    120000.0            Verified  debt_consolidation
# 199990       MORTGAGE    130000.0            Verified  debt_consolidation
# 199991       MORTGAGE     64000.0     Source Verified         credit_card
# 199992       MORTGAGE     74400.0            Verified    home_improvement
# 199993       MORTGAGE    118868.0     Source Verified    home_improvement
# 199994       MORTGAGE     65000.0     Source Verified  debt_consolidation
# 199995       MORTGAGE     44500.0        Not Verified  debt_consolidation
# 199996       MORTGAGE     96500.0            Verified  debt_consolidation
# 199997           RENT     33000.0            Verified  debt_consolidation
# 199998           RENT     75000.0        Not Verified  debt_consolidation
# 199999       MORTGAGE     76800.0        Not Verified  debt_consolidation
#
#         ...  delinq_2yrs  loan_status term_int  emp_length_int  \
# 0       ...          1.0      Current        0              10
# 1       ...          0.0      Current        0               3
# 2       ...          0.0      Current        0               3
# 3       ...          0.0      Current        1               0
# 4       ...          0.0      Current        0              10
# 5       ...          0.0      Current        0              -1
# 6       ...          0.0   Fully Paid        0               4
# 7       ...          0.0      Current        1               1
# 8       ...          0.0   Fully Paid        1               1
# 9       ...          0.0   Fully Paid        0               6
# 11      ...          0.0      Current        0               6
# 12      ...          0.0   Fully Paid        0              10
# 13      ...          0.0      Current        1               0
# 16      ...          0.0      Current        1               0
# 17      ...          0.0      Current        0              -1
# 19      ...          0.0      Current        0              10
# 20      ...          0.0      Current        0               1
# 21      ...          1.0   Fully Paid        0               8
# 22      ...          0.0      Current        0               2
# 23      ...          0.0      Current        1               2
# 24      ...          0.0   Fully Paid        0               2
# 25      ...          0.0   Fully Paid        0              10
# 26      ...          0.0   Fully Paid        0               6
# 27      ...          0.0   Fully Paid        0               3
# 28      ...          0.0   Fully Paid        0              -1
# 29      ...          0.0      Current        0               5
# 30      ...          0.0      Current        1               8
# 31      ...          0.0   Fully Paid        1               3
# 32      ...          0.0   Fully Paid        0               5
# 33      ...          0.0   Fully Paid        1              10
# ...     ...          ...          ...      ...             ...
# 199966  ...          4.0      Current        1               5
# 199967  ...          2.0      Current        1               6
# 199968  ...          0.0   Fully Paid        1              10
# 199970  ...          0.0      Current        1               8
# 199971  ...          0.0   Fully Paid        0              10
# 199972  ...          0.0   Fully Paid        0               3
# 199973  ...          3.0   Fully Paid        0               1
# 199974  ...          0.0      Current        0               3
# 199975  ...          0.0      Current        1              -1
# 199977  ...          0.0   Fully Paid        0              10
# 199978  ...          0.0      Current        0               6
# 199979  ...          1.0      Current        1              10
# 199980  ...          0.0   Fully Paid        1               0
# 199981  ...          0.0   Fully Paid        0               4
# 199982  ...          0.0   Fully Paid        0              10
# 199983  ...          0.0   Fully Paid        0               0
# 199984  ...          0.0      Current        0               5
# 199985  ...          0.0      Current        1               5
# 199988  ...          0.0      Current        0              10
# 199989  ...          0.0   Fully Paid        0               8
# 199990  ...          0.0   Fully Paid        1               8
# 199991  ...          0.0      Current        1               5
# 199992  ...          3.0   Fully Paid        0              -1
# 199993  ...          0.0   Fully Paid        0              10
# 199994  ...          0.0   Fully Paid        0              10
# 199995  ...          0.0   Fully Paid        0               5
# 199996  ...          0.0   Fully Paid        0               9
# 199997  ...          0.0   Fully Paid        0               4
# 199998  ...          0.0      Current        0               7
# 199999  ...          0.0      Current        1               9
#
#         home_ownership_int  verification_status_int  purpose_int  income_tax  \
# 0                        0                        1            1      8175.0
# 1                        0                        1            3         0.0
# 2                        0                        1            3     10350.0
# 3                        1                        2            1      4950.0
# 4                        0                        2            1         0.0
# 5                        0                        0            1         0.0
# 6                        0                        0            3         0.0
# 7                        0                        2            1     19500.0
# 8                        2                        1            1      7500.0
# 9                        1                        2            1         0.0
# 11                       2                        2            1         0.0
# 12                       0                        0            1         0.0
# 13                       0                        1            3         0.0
# 16                       0                        0            1         0.0
# 17                       2                        2            0         0.0
# 19                       0                        1            1      5625.0
# 20                       2                        1            1         0.0
# 21                       2                        0            1         0.0
# 22                       0                        1            3         0.0
# 23                       2                        1            1     11250.0
# 24                       2                        0            3         0.0
# 25                       0                        2            3      5850.0
# 26                       0                        2            1         0.0
# 27                       2                        2            3      7125.0
# 28                       2                        0            1         0.0
# 29                       2                        1            1         0.0
# 30                       0                        0            3      5625.0
# 31                       0                        2            1      5625.0
# 32                       0                        0            2      6750.0
# 33                       0                        2            3         0.0
# ...                    ...                      ...          ...         ...
# 199966                   0                        2            1     12000.0
# 199967                   0                        1            1      6000.0
# 199968                   0                        0            3      8250.0
# 199970                   2                        2            0      6375.0
# 199971                   0                        2            3         0.0
# 199972                   2                        0            1         0.0
# 199973                   2                        0            1      5925.0
# 199974                   2                        0            3      6675.0
# 199975                   2                        1            2      6000.0
# 199977                   2                        0            1      6975.0
# 199978                   1                        1            1         0.0
# 199979                   0                        0            1      9000.0
# 199980                   0                        2            1     13500.0
# 199981                   2                        1            3      5250.0
# 199982                   1                        2            1         0.0
# 199983                   2                        1            1         0.0
# 199984                   0                        1            2     20250.0
# 199985                   0                        2            1         0.0
# 199988                   0                        2            2      9750.0
# 199989                   0                        0            1      9000.0
# 199990                   0                        0            1      9750.0
# 199991                   0                        1            3         0.0
# 199992                   0                        0            2      5580.0
# 199993                   0                        1            2      8915.1
# 199994                   0                        1            1         0.0
# 199995                   0                        2            1         0.0
# 199996                   0                        0            1      7237.5
# 199997                   2                        0            1         0.0
# 199998                   2                        2            1      5625.0
# 199999                   0                        2            1      5760.0
#
#         int_round       target
# 0              14  Non Default
# 1              10  Non Default
# 2              18  Non Default
# 3              18  Non Default
# 4              13  Non Default
# 5              11  Non Default
# 6               8  Non Default
# 7              14  Non Default
# 8               9  Non Default
# 9              15  Non Default
# 11              6  Non Default
# 12             14  Non Default
# 13             12  Non Default
# 16              7  Non Default
# 17             12  Non Default
# 19             15  Non Default
# 20             22  Non Default
# 21             15  Non Default
# 22             11  Non Default
# 23             13  Non Default
# 24             14  Non Default
# 25              6  Non Default
# 26             12  Non Default
# 27              7  Non Default
# 28              5  Non Default
# 29             11  Non Default
# 30             17  Non Default
# 31              8  Non Default
# 32             15  Non Default
# 33             12  Non Default
# ...           ...          ...
# 199966         13  Non Default
# 199967         12  Non Default
# 199968         11  Non Default
# 199970         22  Non Default
# 199971         11  Non Default
# 199972          7  Non Default
# 199973         15  Non Default
# 199974          7  Non Default
# 199975         17  Non Default
# 199977          7  Non Default
# 199978          8  Non Default
# 199979         19  Non Default
# 199980         13  Non Default
# 199981          5  Non Default
# 199982          7  Non Default
# 199983         12  Non Default
# 199984          6  Non Default
# 199985         11  Non Default
# 199988          6  Non Default
# 199989          6  Non Default
# 199990         17  Non Default
# 199991         11  Non Default
# 199992         17  Non Default
# 199993         15  Non Default
# 199994         15  Non Default
# 199995         13  Non Default
# 199996          7  Non Default
# 199997         14  Non Default
# 199998          8  Non Default
# 199999         16  Non Default
#
# [176549 rows x 21 columns]
#         loan_amnt        term  int_rate  installment grade emp_length  \
# 10          35000   60 months     24.08      1008.51     F    9 years
# 14           8400   36 months      9.17       267.79     B  10+ years
# 15          16000   60 months     13.67       369.57     C  10+ years
# 18           7000   36 months     13.49       237.52     C  10+ years
# 36          11200   60 months     13.99       260.55     C  10+ years
# 43          18000   60 months     17.86       455.72     D    9 years
# 44          11475   60 months     20.20       305.30     D    5 years
# 45          20000   60 months     19.99       529.77     E  10+ years
# 56          18000   60 months     21.45       491.53     D    5 years
# 58          15000   36 months     18.99       549.77     D    3 years
# 69          24000   60 months     15.61       578.68     D     1 year
# 71          21000   36 months     12.74       704.95     C  10+ years
# 90          10000   36 months     11.99       332.10     B    8 years
# 99          24000   60 months     14.65       566.56     C  10+ years
# 107         18250   60 months     19.89       482.40     E     1 year
# 129         24000   36 months     21.49       910.26     E  10+ years
# 133          5000   36 months     10.99       163.67     B  10+ years
# 151         12000   36 months     13.99       410.08     C  10+ years
# 154          6000   36 months     13.49       203.59     C  10+ years
# 160          7000   36 months     11.49       230.80     B    7 years
# 171         15600   60 months     19.99       413.22     D    8 years
# 181         12000   36 months     13.49       407.17     C     1 year
# 188         20000   36 months     12.59       669.94     C    3 years
# 189         26500   60 months     25.99       793.27     F    8 years
# 191         30000   60 months     14.65       708.20     C    4 years
# 193         15000   36 months     18.25       544.17     D  10+ years
# 194         12000   36 months     11.99       398.52     C  10+ years
# 201         12000   60 months     18.54       308.26     E    8 years
# 205          2400   36 months     14.33        82.42     C    4 years
# 210          8400   36 months     13.68       285.79     C    3 years
# ...           ...         ...       ...          ...   ...        ...
# 199812      10000   36 months     13.99       341.73     C  10+ years
# 199815      18000   36 months     13.99       615.11     C    6 years
# 199819      17000   60 months     13.99       395.48     C  10+ years
# 199822      15000   60 months     14.33       351.60     C  10+ years
# 199830       9050   36 months     17.57       325.24     D    2 years
# 199833      21000   36 months     12.35       701.02     B  10+ years
# 199842       8950   36 months     16.59       317.27     D    6 years
# 199846      24600   36 months     12.62       824.38     C        NaN
# 199856      10000   36 months     12.88       336.37     C    9 years
# 199861       3625   36 months     13.99       123.88     C        NaN
# 199864      12800   60 months     13.68       295.72     C    6 years
# 199874       4800   36 months     17.27       171.78     D    2 years
# 199880      24000   60 months     17.86       607.62     D    4 years
# 199889      35000   36 months     14.30      1201.33     C  10+ years
# 199890      24000   60 months     13.33       550.14     C  10+ years
# 199895      19750   60 months     24.89       578.42     G    9 years
# 199903      17750   60 months     15.61       427.98     C  10+ years
# 199911      10000   36 months     16.78       355.44     C        NaN
# 199926      19050   60 months     21.67       522.58     E  10+ years
# 199932      21000   60 months     14.65       495.74     C     1 year
# 199943      12000   36 months     15.61       419.58     D    9 years
# 199944      35000   60 months     15.99       850.95     C  10+ years
# 199946       7000   36 months     15.59       244.69     D    3 years
# 199949       5000   36 months     18.54       182.12     E        NaN
# 199951      18050   60 months     18.55       463.77     E    3 years
# 199959      24550   36 months     17.97       887.18     D    4 years
# 199969      10000   36 months      7.62       311.62     A  10+ years
# 199976      14100   36 months     13.58       479.04     C    6 years
# 199986      35000   36 months     16.55      1240.03     D  10+ years
# 199987      10000   60 months     19.22       260.62     D    8 years
#
#        home_ownership  annual_inc verification_status             purpose  \
# 10               RENT    100000.0            Verified         credit_card
# 14           MORTGAGE     55000.0        Not Verified         credit_card
# 15           MORTGAGE     73000.0        Not Verified         credit_card
# 18           MORTGAGE     60000.0            Verified    home_improvement
# 36           MORTGAGE     80000.0     Source Verified  debt_consolidation
# 43               RENT     45000.0     Source Verified         credit_card
# 44           MORTGAGE     46000.0            Verified  debt_consolidation
# 45               RENT     50000.0     Source Verified  debt_consolidation
# 56           MORTGAGE     82000.0            Verified  debt_consolidation
# 58           MORTGAGE     71300.0        Not Verified               other
# 69           MORTGAGE     48000.0        Not Verified  debt_consolidation
# 71           MORTGAGE    120000.0        Not Verified         credit_card
# 90               RENT     40000.0        Not Verified         credit_card
# 99           MORTGAGE     70000.0        Not Verified  debt_consolidation
# 107               OWN     36500.0     Source Verified  debt_consolidation
# 129              RENT     59000.0            Verified         credit_card
# 133              RENT     90000.0        Not Verified  debt_consolidation
# 151              RENT    100000.0     Source Verified  debt_consolidation
# 154               OWN    130000.0     Source Verified  debt_consolidation
# 160              RENT     50000.0        Not Verified  debt_consolidation
# 171               OWN     40000.0     Source Verified         credit_card
# 181              RENT     90000.0     Source Verified  debt_consolidation
# 188              RENT     87000.0            Verified  debt_consolidation
# 189          MORTGAGE    108000.0     Source Verified  debt_consolidation
# 191              RENT     71000.0     Source Verified  debt_consolidation
# 193          MORTGAGE     61000.0            Verified  debt_consolidation
# 194              RENT     52231.0        Not Verified               other
# 201              RENT     30000.0     Source Verified  debt_consolidation
# 205          MORTGAGE     83000.0            Verified  debt_consolidation
# 210              RENT    105000.0     Source Verified  debt_consolidation
# ...               ...         ...                 ...                 ...
# 199812       MORTGAGE     58000.0        Not Verified  debt_consolidation
# 199815           RENT     41000.0     Source Verified  debt_consolidation
# 199819           RENT     60000.0            Verified  debt_consolidation
# 199822       MORTGAGE     95000.0        Not Verified  debt_consolidation
# 199830           RENT     30000.0     Source Verified               other
# 199833       MORTGAGE     75000.0     Source Verified         credit_card
# 199842           RENT     40000.0        Not Verified         credit_card
# 199846       MORTGAGE     30000.0            Verified  debt_consolidation
# 199856           RENT     95000.0     Source Verified         credit_card
# 199861           RENT     60000.0            Verified               other
# 199864           RENT     43000.0     Source Verified  debt_consolidation
# 199874           RENT     35000.0            Verified  debt_consolidation
# 199880           RENT     72000.0     Source Verified      major_purchase
# 199889       MORTGAGE    400000.0            Verified               other
# 199890       MORTGAGE    105000.0        Not Verified  debt_consolidation
# 199895           RENT     66000.0            Verified  debt_consolidation
# 199903       MORTGAGE     39500.0            Verified         credit_card
# 199911           RENT     30000.0            Verified  debt_consolidation
# 199926           RENT     53000.0     Source Verified  debt_consolidation
# 199932           RENT     84030.0            Verified  debt_consolidation
# 199943           RENT     50000.0            Verified  debt_consolidation
# 199944       MORTGAGE    130000.0            Verified  debt_consolidation
# 199946           RENT     70000.0     Source Verified  debt_consolidation
# 199949            OWN     10212.0            Verified  debt_consolidation
# 199951           RENT     43000.0            Verified         credit_card
# 199959            OWN    120000.0            Verified  debt_consolidation
# 199969       MORTGAGE    120000.0        Not Verified         credit_card
# 199976           RENT     42000.0        Not Verified         credit_card
# 199986       MORTGAGE    153000.0     Source Verified  debt_consolidation
# 199987           RENT     42000.0            Verified  debt_consolidation
#
#         ...  delinq_2yrs  loan_status term_int  emp_length_int  \
# 10      ...          1.0  Charged Off        1               9
# 14      ...          0.0  Charged Off        0              10
# 15      ...          1.0  Charged Off        1              10
# 18      ...          0.0  Charged Off        0              10
# 36      ...          0.0  Charged Off        1              10
# 43      ...          0.0  Charged Off        1               9
# 44      ...          0.0  Charged Off        1               5
# 45      ...          0.0  Charged Off        1              10
# 56      ...          0.0  Charged Off        1               5
# 58      ...          0.0  Charged Off        0               3
# 69      ...          0.0  Charged Off        1               1
# 71      ...          0.0  Charged Off        0              10
# 90      ...          0.0  Charged Off        0               8
# 99      ...          0.0  Charged Off        1              10
# 107     ...          0.0  Charged Off        1               1
# 129     ...          0.0  Charged Off        0              10
# 133     ...          0.0  Charged Off        0              10
# 151     ...          2.0  Charged Off        0              10
# 154     ...          0.0  Charged Off        0              10
# 160     ...          0.0  Charged Off        0               7
# 171     ...          0.0  Charged Off        1               8
# 181     ...          3.0  Charged Off        0               1
# 188     ...          0.0  Charged Off        0               3
# 189     ...          1.0  Charged Off        1               8
# 191     ...          0.0  Charged Off        1               4
# 193     ...          0.0  Charged Off        0              10
# 194     ...          0.0  Charged Off        0              10
# 201     ...          0.0  Charged Off        1               8
# 205     ...          0.0  Charged Off        0               4
# 210     ...          1.0  Charged Off        0               3
# ...     ...          ...          ...      ...             ...
# 199812  ...          0.0  Charged Off        0              10
# 199815  ...          0.0  Charged Off        0               6
# 199819  ...          0.0  Charged Off        1              10
# 199822  ...          0.0  Charged Off        1              10
# 199830  ...          0.0  Charged Off        0               2
# 199833  ...          0.0  Charged Off        0              10
# 199842  ...          0.0  Charged Off        0               6
# 199846  ...          0.0  Charged Off        0              -1
# 199856  ...          0.0  Charged Off        0               9
# 199861  ...          0.0  Charged Off        0              -1
# 199864  ...          0.0  Charged Off        1               6
# 199874  ...          0.0  Charged Off        0               2
# 199880  ...          0.0  Charged Off        1               4
# 199889  ...          0.0  Charged Off        0              10
# 199890  ...          0.0  Charged Off        1              10
# 199895  ...          3.0  Charged Off        1               9
# 199903  ...          2.0  Charged Off        1              10
# 199911  ...          0.0  Charged Off        0              -1
# 199926  ...          0.0  Charged Off        1              10
# 199932  ...          0.0  Charged Off        1               1
# 199943  ...          0.0  Charged Off        0               9
# 199944  ...          3.0  Charged Off        1              10
# 199946  ...          0.0  Charged Off        0               3
# 199949  ...          0.0  Charged Off        0              -1
# 199951  ...          0.0  Charged Off        1               3
# 199959  ...          0.0  Charged Off        0               4
# 199969  ...          0.0  Charged Off        0              10
# 199976  ...          0.0  Charged Off        0               6
# 199986  ...          1.0  Charged Off        0              10
# 199987  ...          0.0  Charged Off        1               8
#
#         home_ownership_int  verification_status_int  purpose_int  income_tax  \
# 10                       2                        0            3     7500.00
# 14                       0                        2            3        0.00
# 15                       0                        2            3     5475.00
# 18                       0                        0            2        0.00
# 36                       0                        1            1     6000.00
# 43                       2                        1            3        0.00
# 44                       0                        0            1        0.00
# 45                       2                        1            1        0.00
# 56                       0                        0            1     6150.00
# 58                       0                        2            0     5347.50
# 69                       0                        2            1        0.00
# 71                       0                        2            3     9000.00
# 90                       2                        2            3        0.00
# 99                       0                        2            1     5250.00
# 107                      1                        1            1        0.00
# 129                      2                        0            3        0.00
# 133                      2                        2            1     6750.00
# 151                      2                        1            1     7500.00
# 154                      1                        1            1     9750.00
# 160                      2                        2            1        0.00
# 171                      1                        1            3        0.00
# 181                      2                        1            1     6750.00
# 188                      2                        0            1     6525.00
# 189                      0                        1            1     8100.00
# 191                      2                        1            1     5325.00
# 193                      0                        0            1        0.00
# 194                      2                        2            0        0.00
# 201                      2                        1            1        0.00
# 205                      0                        0            1     6225.00
# 210                      2                        1            1     7875.00
# ...                    ...                      ...          ...         ...
# 199812                   0                        2            1        0.00
# 199815                   2                        1            1        0.00
# 199819                   2                        0            1        0.00
# 199822                   0                        2            1     7125.00
# 199830                   2                        1            0        0.00
# 199833                   0                        1            3     5625.00
# 199842                   2                        2            3        0.00
# 199846                   0                        0            1        0.00
# 199856                   2                        1            3     7125.00
# 199861                   2                        0            0        0.00
# 199864                   2                        1            1        0.00
# 199874                   2                        0            1        0.00
# 199880                   2                        1            7     5400.00
# 199889                   0                        0            0    30000.00
# 199890                   0                        2            1     7875.00
# 199895                   2                        0            1     4950.00
# 199903                   0                        0            3        0.00
# 199911                   2                        0            1        0.00
# 199926                   2                        1            1        0.00
# 199932                   2                        0            1     6302.25
# 199943                   2                        0            1        0.00
# 199944                   0                        0            1     9750.00
# 199946                   2                        1            1     5250.00
# 199949                   1                        0            1        0.00
# 199951                   2                        0            3        0.00
# 199959                   1                        0            1     9000.00
# 199969                   0                        2            3     9000.00
# 199976                   2                        2            3        0.00
# 199986                   0                        1            1    11475.00
# 199987                   2                        0            1        0.00
#
#         int_round   target
# 10             24  Default
# 14              9  Default
# 15             13  Default
# 18             13  Default
# 36             13  Default
# 43             17  Default
# 44             20  Default
# 45             19  Default
# 56             21  Default
# 58             18  Default
# 69             15  Default
# 71             12  Default
# 90             11  Default
# 99             14  Default
# 107            19  Default
# 129            21  Default
# 133            10  Default
# 151            13  Default
# 154            13  Default
# 160            11  Default
# 171            19  Default
# 181            13  Default
# 188            12  Default
# 189            25  Default
# 191            14  Default
# 193            18  Default
# 194            11  Default
# 201            18  Default
# 205            14  Default
# 210            13  Default
# ...           ...      ...
# 199812         13  Default
# 199815         13  Default
# 199819         13  Default
# 199822         14  Default
# 199830         17  Default
# 199833         12  Default
# 199842         16  Default
# 199846         12  Default
# 199856         12  Default
# 199861         13  Default
# 199864         13  Default
# 199874         17  Default
# 199880         17  Default
# 199889         14  Default
# 199890         13  Default
# 199895         24  Default
# 199903         15  Default
# 199911         16  Default
# 199926         21  Default
# 199932         14  Default
# 199943         15  Default
# 199944         15  Default
# 199946         15  Default
# 199949         18  Default
# 199951         18  Default
# 199959         17  Default
# 199969          7  Default
# 199976         13  Default
# 199986         16  Default
# 199987         19  Default
#
# [23451 rows x 21 columns]

# %% [markdown]
# ### Section 2 & 3 - Visualise and Save Figure
#
# Create subplots of 2 rows and 2 columns, creating 4 different axes and plotting them one by one.
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/kmlZpPY.png" width=800>

# %%
# -------------- #
### SECTION 2 ###
## VISUALISE ## 
# -------------- #

figure = plt.figure(figsize=(16,12))

ax1 = figure.add_subplot(2,2,1)
ax2 = figure.add_subplot(2,2,2)
ax3 = figure.add_subplot(2,2,3)
ax4 = figure.add_subplot(2,2,4)

sns.set(style = "ticks")
sns.distplot(non_default_df['loan_amnt'], ax=ax1)
ax1.set(ylabel = '% of', xlabel = 'Loan Amount', title = 'Non-Default Loan Amount Distribution')

sns.distplot(default_df['loan_amnt'], ax=ax2, color='red')
ax2.set(ylabel = '% of', xlabel = 'Loan Amount', title = 'Default Loan Amount Distribution')

sns.countplot(x = 'int_round', data = non_default_df, ax=ax3, color='blue')
ax3.set(ylabel = 'Count', xlabel = 'Interest Rate ($)', title = 'Non-Default Interest Rate Distribution')

sns.countplot(x = 'int_round', data = default_df, ax=ax4, color='red')
ax4.set(ylabel = 'Count', xlabel = 'Interest Rate ($)', title = 'Default Interest Rate Distribution')

figure.suptitle('Non-Default vs. Default Loan Distribution')
# -------------- #
### SECTION 3 ###
## SAVE FIGURE ## 
# -------------- #

plt.savefig('Non-Default vs Default Loan Distribution.png')

# %%
## TA/INSTRUCTOR ONLY
## SECTION 1: 1/1
## SECTION 2: 1/1
## SECTION 3: 1/1

# %% [markdown]
# ### Question 10 - Grade by Grade Distribution
#
# <i><b>This question is challenging.</b> There may be other ways to solve this question; the following sections are just one way of solving it.</i>
#
# You are interested in comparing each grade side by side, looking specifically at the loan amount and interest rate involved in each loan.

# %% [markdown]
# ### Section 1 - Prepare Data
#
# Create a <b>list of DataFrames</b> where each DataFrame is a grade (`A`, `B` ... `G`) and has only 2 columns, `loan_amnt` and `int_round`.
#
# <b>Expected output: </b>
#
#     [        loan_amnt  int_round
#      11           4000          6
#      16          35000          7
#      25           7200          6
#      27          25000          7
#      28          24000          5
#      ...           ...        ...
#      199982       9000          7
#      199984      25000          6
#      199988      15000          6
#      199989      29025          6
#      199996      30000          7
#
#      [38162 rows x 2 columns],         loan_amnt  int_round
#      1            8000         10
#      5           20000         11
#      6           12000          8
#      8           20000          9
#      12          15350         14
#      ...           ...        ...
#      199971      13000         11
#      199978      14000          8
#      199985      12000         11
#      199991      15000         11
#      199998      10000          8
#      ....
#      ]

# %%
all_loans_df.head()

list_of_df = []
list_of_grade = list(all_loans_df['grade'].unique())
list_of_grade.sort()

for grade in list_of_grade:
    cond = (all_loans_df['grade'] == grade)
    grade_df = all_loans_df[cond]
    filtered_df = grade_df[['loan_amnt','int_round']]
    list_of_df.append(filtered_df)
print(list_of_df)
# Out:
# [        loan_amnt  int_round
# 11           4000          6
# 16          35000          7
# 25           7200          6
# 27          25000          7
# 28          24000          5
# 61           5000          7
# 68          15000          7
# 74          25000          7
# 75          10000          6
# 76          10000          7
# 79           5000          7
# 81          40000          6
# 88           7000          7
# 89          16000          8
# 92           9000          6
# 102          6000          8
# 104          5000          7
# 116          5000          6
# 126         24800          7
# 135          8000          6
# 136          9000          7
# 144          9600          7
# 145         13500          8
# 150         10000          7
# 165          8000          6
# 168         24000          7
# 172         15000          8
# 173          7300          6
# 176         25000          8
# 179          4800          7
# ...           ...        ...
# 199866      25000          8
# 199867       2000          7
# 199876      21000          7
# 199884      35000          7
# 199897      21725          8
# 199901      30000          5
# 199909       7000          7
# 199910       5000          7
# 199913       6000          8
# 199916      20000          6
# 199917      30000          7
# 199922      15000          7
# 199923       6400          7
# 199924      15000          7
# 199928      11000          8
# 199930      10000          7
# 199933      10000          7
# 199945      22000          6
# 199947      10000          6
# 199965      35000          6
# 199969      10000          7
# 199972       5100          7
# 199974      16000          7
# 199977      18000          7
# 199981      10000          5
# 199982       9000          7
# 199984      25000          6
# 199988      15000          6
# 199989      29025          6
# 199996      30000          7
#
# [38162 rows x 2 columns],         loan_amnt  int_round
# 1            8000         10
# 5           20000         11
# 6           12000          8
# 8           20000          9
# 12          15350         14
# 14           8400          9
# 17           8000         12
# 22           6000         11
# 24           6000         14
# 29           8000         11
# 31          20000          8
# 35           9000         10
# 37          12500          9
# 38           8000         10
# 39          15000         11
# 41           6000         10
# 46          15000          9
# 48          24000         13
# 55          23450         11
# 59           5750         10
# 60          23000          9
# 70          12000          9
# 72           6000         12
# 77          15000         10
# 82          29000         11
# 85           6000          9
# 86          12000         10
# 90          10000         11
# 94          15000          9
# 103         10000         11
# ...           ...        ...
# 199873      12000         12
# 199881      14000         12
# 199882      20000          9
# 199883       2500         10
# 199887       5000          8
# 199888      14400         12
# 199891      36000         10
# 199896      15000         11
# 199898      15000          9
# 199905      35000          9
# 199915      22000          9
# 199919       4800         10
# 199934      21000         11
# 199936      30000         10
# 199937      24000         11
# 199939       3500         11
# 199940       3000          9
# 199941      30000          9
# 199948      10975          9
# 199950      12000          9
# 199954       6000          8
# 199960       6000         11
# 199962       4000          9
# 199963      10000          9
# 199968      35000         11
# 199971      13000         11
# 199978      14000          8
# 199985      12000         11
# 199991      15000         11
# 199998      10000          8
#
# [58533 rows x 2 columns],         loan_amnt  int_round
# 0           14400         14
# 4            6800         13
# 7           40000         14
# 9            6000         15
# 13          14000         12
# 15          16000         13
# 18           7000         13
# 19          12000         15
# 21          20000         15
# 23          18000         13
# 26           6000         12
# 33          25000         12
# 36          11200         13
# 40          10500         14
# 47          10000         16
# 49          25000         13
# 50          15000         14
# 51           1000         13
# 52           9600         13
# 53           3000         14
# 54           6375         13
# 57          25000         13
# 63          21000         15
# 66          10000         13
# 67          10000         15
# 71          21000         12
# 80          20000         15
# 83          12000         12
# 84          13850         13
# 87          20000         15
# ...           ...        ...
# 199899       4000         13
# 199900      15000         16
# 199903      17750         15
# 199904      14000         13
# 199906      20225         13
# 199907      20000         13
# 199911      10000         16
# 199912      19175         14
# 199920      15000         15
# 199925      19000         12
# 199927      16000         12
# 199929      20525         12
# 199931      10000         15
# 199932      21000         14
# 199935      24000         13
# 199944      35000         15
# 199952       8000         12
# 199955       8000         15
# 199956      20000         12
# 199958      16000         13
# 199964       8400         12
# 199966      25000         13
# 199967      24000         12
# 199973      24000         15
# 199976      14100         13
# 199980      20000         13
# 199983       6000         12
# 199994      20000         15
# 199995      12000         13
# 199997       9600         14
#
# [57673 rows x 2 columns],         loan_amnt  int_round
# 2            9500         18
# 3           16000         18
# 30          35000         17
# 32           2500         15
# 42           9350         15
# 43          18000         17
# 44          11475         20
# 56          18000         21
# 58          15000         18
# 65          22000         16
# 69          24000         15
# 73           5000         18
# 78          22000         21
# 95          10000         17
# 100         10000         22
# 120         30000         20
# 123         12000         19
# 130         26000         20
# 146         16000         17
# 159         12000         18
# 171         15600         19
# 180         10000         17
# 184          6925         17
# 193         15000         18
# 204         11000         20
# 213         16000         17
# 216         24000         17
# 220          8325         17
# 222         40000         17
# 227         11700         15
# ...           ...        ...
# 199842       8950         16
# 199844       3000         17
# 199857       6000         21
# 199859      20000         17
# 199868      18000         15
# 199874       4800         17
# 199875      35000         17
# 199877       6400         16
# 199880      24000         17
# 199885       3600         18
# 199892       5500         17
# 199902      40000         17
# 199908      30000         17
# 199914      10500         18
# 199938       9600         18
# 199942      20000         19
# 199943      12000         15
# 199946       7000         15
# 199953      20000         20
# 199959      24550         17
# 199961      13575         16
# 199970      13500         22
# 199975      15000         17
# 199979      30000         19
# 199986      35000         16
# 199987      10000         19
# 199990      16000         17
# 199992       8200         17
# 199993      35000         15
# 199999      25000         16
#
# [28844 rows x 2 columns],         loan_amnt  int_round
# 20          20000         22
# 45          20000         19
# 62          12025         27
# 96          19000         16
# 107         18250         19
# 113          5050         24
# 129         24000         21
# 163         29325         18
# 201         12000         18
# 235         23325         21
# 252         16125         20
# 265         14000         18
# 304          7500         24
# 310         20000         18
# 334         20000         21
# 338         12000         22
# 366          9350         24
# 370         17000         16
# 424          3600         20
# 439         15300         25
# 475         12250         18
# 493          5950         18
# 501         30000         26
# 510         35000         17
# 518         16150         20
# 532         18000         18
# 533         23100         21
# 555          8875         18
# 572         12075         20
# 576         16000         22
# ...           ...        ...
# 199529       3600         20
# 199532      26400         19
# 199552      16000         24
# 199557      16700         22
# 199579      16100         20
# 199582       4400         19
# 199586      15200         25
# 199600       9250         22
# 199616      21000         20
# 199631      24000         25
# 199636      30000         18
# 199639      13300         21
# 199644      16000         27
# 199694       6400         23
# 199702      13000         18
# 199716      14125         23
# 199746      12600         18
# 199763      35000         24
# 199773      20000         27
# 199786      11000         26
# 199799       6000         20
# 199806       2000         25
# 199825      28500         18
# 199863      18000         20
# 199918      32400         26
# 199921      35000         19
# 199926      19050         21
# 199949       5000         18
# 199951      18050         18
# 199957      10500         18
#
# [11941 rows x 2 columns],         loan_amnt  int_round
# 10          35000         24
# 34           3400         24
# 64          14875         26
# 189         26500         25
# 282         10500         21
# 330          1600         29
# 378         16325         24
# 408          9450         25
# 468         15200         29
# 473         19000         27
# 489         15200         21
# 540         35000         22
# 630         13500         25
# 795         25000         23
# 941         11500         25
# 962         14000         28
# 1066         5325         28
# 1072        12325         22
# 1180        15100         30
# 1218        20000         24
# 1277        12000         30
# 1454        20800         30
# 1459        20000         28
# 1561        20000         22
# 1575        20000         29
# 1647        22000         26
# 1695        16975         22
# 1719        23725         25
# 1753        25000         30
# 1817        24000         19
# ...           ...        ...
# 198478      25000         25
# 198581      19000         25
# 198669       1200         23
# 198740      35000         25
# 198776      19425         25
# 198801      10075         27
# 198849      12000         24
# 198897      13700         23
# 198945      20475         25
# 198946      21175         25
# 199013      35000         25
# 199040      21350         30
# 199094      12000         29
# 199130      18500         24
# 199170       5000         24
# 199237      35000         24
# 199281      35000         21
# 199294      20000         28
# 199344      20475         23
# 199372      32000         19
# 199388      22000         28
# 199425      33225         25
# 199429      12000         26
# 199478      32000         23
# 199479      10000         24
# 199481      18000         23
# 199531      32000         24
# 199669       5125         22
# 199759      35000         25
# 199893      20000         30
#
# [3820 rows x 2 columns],         loan_amnt  int_round
# 353         35000         25
# 393         21000         30
# 711         11950         28
# 811         26600         26
# 874         11475         28
# 921         11550         25
# 1007        15000         30
# 1040        11700         25
# 1049        26950         25
# 1262        22400         27
# 1267        10775         26
# 1418        10100         28
# 1799        13675         28
# 1852        11850         25
# 2083        10000         30
# 2159        26650         25
# 2324        10000         30
# 2438        25000         30
# 2482        16300         25
# 2558        35000         24
# 2599        24000         29
# 2655        13300         30
# 3452        20000         30
# 3520         6400         16
# 3616        17775         30
# 3624        23200         23
# 3789        11150         30
# 3986         4650         30
# 4052        34425         30
# 4055        15000         30
# ...           ...        ...
# 193413      35000         24
# 193593      20000         25
# 194145      35000         30
# 194563      36000         30
# 194937      11200         30
# 195072      21850         30
# 195102      30000         22
# 195110      15500         26
# 195147      35000         30
# 195662      14000         28
# 195717      16800         30
# 195755      34125         27
# 195860      10650         25
# 195865      22000         25
# 195957      18850         27
# 196092      35000         30
# 196453      13525         30
# 197121      25000         21
# 197167      11200         30
# 197196      22800         28
# 197412      30000         30
# 197716      25825         30
# 198308       4275         25
# 198449      30000         30
# 198476      10000         25
# 198568      13500         30
# 199111      16475         26
# 199120      16000         30
# 199241      11225         27
# 199895      19750         24
#
# [1027 rows x 2 columns]]

# %% [markdown]
# ### Section 2 & 3 - Visualise and Save Figure
#
# Suggested Pseudocode:
#
# 1. Create two lists:
#     - 1 list for colors to format each row of chart with one color
#     - 1 list of strings with grades A to G, to format the titles accordingly
#
#
# 2. Create subplots with 7 rows (A to G for each row) and 2 columns (Loan Amount and Interest Rate columns), by using `plt.subplots()`.
# 3. From the above code, get the Axes, which gives a 2-D list of lists, where each list is a row (which is also a list). Each row contains multiple Axes, in this case its 2 axes. For example:
#
#     [
#         [Ax1, Ax2] # Row 0
#         ...
#     ]
#
#
# 4. Loop through each grade from the list of DataFrames above
# 5. Extract out each axes and store them as variables
# 6. With each axes, plot the DataFrame, with the first ax using `sns.distplot()` and second ax using `sns.countplot()`.
# 7. With every iteration of the loop, change the grade and color
#
# Once you've managed to visualise this, save the figure as `grade_by_grade_distribution.png`.
#
# <b>Expected Output:</b>
#
# <img src="https://i.imgur.com/YHZgmb6.png" width=800>

# %%
list_of_grade = list(all_loans_df['grade'].unique())
list_of_grade.sort()
list_of_colours = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'olive']

# %%
# -------------- #
### SECTION 2 ###
## VISUALISE ## 
# -------------- #
sns.set(style = "ticks")

fig, axs = plt.subplots(nrows=7,ncols=2,figsize = (15,20))

fig.subplots_adjust(hspace = 0.5,
                   wspace = 0.3)

for i in range(len(axs)):
    for j in range(2):
        ax = axs[i][j]
        if(j == 0):
            sns.distplot(list_of_df[i]['loan_amnt'], ax=ax, color=list_of_colours[i])
            ax.set(ylabel = '% of', xlabel = 'Loan Amount ($)', title = 'Grade ' + list_of_grade[i] + ' Loan Amount Distribution')
        else:
            sns.countplot(x = 'int_round', data = list_of_df[i], ax=ax, color=list_of_colours[i])
            ax.set(ylabel = 'Count', xlabel = 'Interest Rate ($)', title = 'Grade ' + list_of_grade[i] + ' Interest Rate Distribution')

fig.suptitle('Grade by Grade Distribution')

# -------------- #
### SECTION 3 ###
## SAVE FIGURE ## 
# -------------- #

plt.savefig('grade_by_grade_distribution.png')

# %%
## TA/INSTRUCTOR ONLY
## SECTION 1: 1/1
## SECTION 2: 1/1
## SECTION 3: 1/1

# %% [markdown]
# ### Optional - Analysis Comments (No marks but possibly insightful)
#
# Add any additional comments/insights about this problem sets and our teaching team could reply to it.

# %% [markdown]
# <div class="alert alert-success">
# <b>Checkpoint</b>: When you have completed Part 2, upload your progress to eLearn. eLearn only accepts the latest notebooks so if you have an existing notebook, your latest upload will <b>override</b> it.
# </div>
